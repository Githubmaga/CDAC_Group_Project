# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
import string
from nltk.tokenize import word_tokenize
from sklearn.model_selection import train_test_split

# %%
toys_df = pd.read_json("D:\CDAC_PUNE_PROJECT\Toys_and_Games.json\Toys_and_Games.json",lines=True)

# %%
toys_df.head(10)
# Out:
#                                     _id      reviewerID        asin  \
# 0  {'$oid': '5a13282b741a2384e879a620'}  A3C9CSW3TJITGT  0005069491
# 1  {'$oid': '5a13282b741a2384e879a621'}  A31POTIYCKSZ9G  0076561046
# 2  {'$oid': '5a13282b741a2384e879a622'}  A2GGHHME9B6W4O  0131358936
# 3  {'$oid': '5a13282b741a2384e879a61f'}   AMEVO2LY6VEJA  0000191639
# 4  {'$oid': '5a13282b741a2384e879a623'}  A1FSLDH43ORWZP  0133642984
# 5  {'$oid': '5a13282b741a2384e879a624'}  A3NXHTSEBX9YHB  0279515766
# 6  {'$oid': '5a13282b741a2384e879a626'}  A3CJHKFHHQJP2K  0375829695
# 7  {'$oid': '5a13282b741a2384e879a627'}  A3638FINP26E8N  0375829695
# 8  {'$oid': '5a13282b741a2384e879a62a'}  A1QG5NJW3LOTSO  0375829695
# 9  {'$oid': '5a13282b741a2384e879a629'}  A27GZ92KLXDJVJ  0375829695
#
#            reviewerName helpful  \
# 0                 Renee  [0, 0]
# 1         So CA Teacher  [0, 0]
# 2            Dalilah G.  [0, 0]
# 3         Nicole Soeder  [0, 0]
# 4         Dayna English  [0, 0]
# 5        marlenetbueras  [0, 0]
# 6  Beth Sharo "bookmom"  [0, 0]
# 7             C. Boykin  [1, 1]
# 8               H. Chao  [0, 0]
# 9              D. Glade  [1, 1]
#
#                                           reviewText  overall  \
# 0  I love these felt nursery rhyme characters and...        4
# 1  I see no directions for its use. Therefore I h...        3
# 2  This is a great tool for any teacher using the...        5
# 3  Great product, thank you! Our son loved the pu...        5
# 4  Although not as streamlined as the Algebra I m...        5
# 5  i am glad to get it after 25 yr of waiting for...        5
# 6  My son got this book for his birthday.  He lov...        1
# 7  Love the book format. My 4yr old grandson love...        3
# 8  On the plus side - puzzle book format and deli...        3
# 9  This puzzle is poorly made.  The picture part ...        2
#
#                                       summary  unixReviewTime   reviewTime  \
# 0  Charming characters but busy work required      1377561600  08 27, 2013
# 1                    No directions for use...      1404864000   07 9, 2014
# 2                                Great CD-ROM      1382400000  10 22, 2013
# 3                                     Puzzles      1388016000  12 26, 2013
# 4        Algebra II -- presentation materials      1374278400  07 20, 2013
# 5                     my strawberry shortcake      1363564800  03 18, 2013
# 6                   Disappointing Puzzle Book      1297209600   02 9, 2011
# 7                   frustrating puzzle pieces      1282521600  08 23, 2010
# 8                              mixed feelings      1201564800  01 29, 2008
# 9     Cheaply made puzzle - not worth your $!      1264550400  01 27, 2010
#
#          category  class
# 0  Toys_and_Games      1
# 1  Toys_and_Games      0
# 2  Toys_and_Games      1
# 3  Toys_and_Games      1
# 4  Toys_and_Games      1
# 5  Toys_and_Games      1
# 6  Toys_and_Games      0
# 7  Toys_and_Games      0
# 8  Toys_and_Games      0
# 9  Toys_and_Games      0

# %%
df=toys_df[['reviewText','class']]

# %%
df.head()
# Out:
#                                           reviewText  class
# 0  I love these felt nursery rhyme characters and...      1
# 1  I see no directions for its use. Therefore I h...      0
# 2  This is a great tool for any teacher using the...      1
# 3  Great product, thank you! Our son loved the pu...      1
# 4  Although not as streamlined as the Algebra I m...      1

# %%
df['class'].value_counts()
# Out:
# class
# 1    1662754
# 0     334386
# Name: count, dtype: int64

# %%
x=df['reviewText']
y=df['class']

# %%
train_sent,test_sent,train_labels,test_labels=train_test_split(x,y,stratify=y,test_size=0.3,random_state=0)

# %%
test_sent.count()
# Out:
# 599142

# %%
vocab_size = 10000
embedding_dim = 16
max_length = 120
trunc_type = 'post'

# %%
! pip install keras_preprocessing
# Out:
# Requirement already satisfied: keras_preprocessing in c:\users\prathamesh\anaconda3\envs\deep_learning\lib\site-packages (1.1.2)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\prathamesh\anaconda3\envs\deep_learning\lib\site-packages (from keras_preprocessing) (1.24.3)
# Requirement already satisfied: six>=1.9.0 in c:\users\prathamesh\anaconda3\envs\deep_learning\lib\site-packages (from keras_preprocessing) (1.16.0)

# %%
from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
tokenizer = Tokenizer(num_words=vocab_size)
tokenizer.fit_on_texts(train_sent)
word_index=tokenizer.word_index
len(word_index)
# Out:
# WARNING:tensorflow:From c:\Users\Prathamesh\anaconda3\envs\Deep_Learning\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# 300029

# %%
word_index
# Out:
# {'the': 1,
#  'and': 2,
#  'it': 3,
#  'a': 4,
#  'to': 5,
#  'i': 6,
#  'is': 7,
#  'this': 8,
#  'for': 9,
#  'of': 10,
#  'my': 11,
#  'with': 12,
#  'in': 13,
#  'that': 14,
#  'was': 15,
#  'but': 16,
#  'on': 17,
#  'you': 18,
#  'are': 19,
#  'have': 20,
#  'as': 21,
#  'not': 22,
#  'so': 23,
#  'they': 24,
#  'very': 25,
#  'one': 26,
#  'we': 27,
#  'great': 28,
#  'he': 29,
#  'be': 30,
#  'all': 31,
#  'them': 32,
#  'she': 33,
#  'old': 34,
#  'just': 35,
#  'like': 36,
#  'game': 37,
#  'at': 38,
#  'would': 39,
#  'can': 40,
#  'toy': 41,
#  'has': 42,
#  "it's": 43,
#  'when': 44,
#  'up': 45,
#  'if': 46,
#  'her': 47,
#  'or': 48,
#  'little': 49,
#  'out': 50,
#  'had': 51,
#  'year': 52,
#  'these': 53,
#  'will': 54,
#  'fun': 55,
#  'loves': 56,
#  'get': 57,
#  'well': 58,
#  'more': 59,
#  'play': 60,
#  'love': 61,
#  'good': 62,
#  'from': 63,
#  'really': 64,
#  'bought': 65,
#  'time': 66,
#  'his': 67,
#  'only': 68,
#  'son': 69,
#  'an': 70,
#  'kids': 71,
#  'other': 72,
#  'about': 73,
#  'than': 74,
#  'got': 75,
#  'there': 76,
#  'set': 77,
#  'were': 78,
#  'much': 79,
#  'also': 80,
#  'daughter': 81,
#  'some': 82,
#  'our': 83,
#  '2': 84,
#  'your': 85,
#  'do': 86,
#  'because': 87,
#  'too': 88,
#  'what': 89,
#  'no': 90,
#  'even': 91,
#  'use': 92,
#  'made': 93,
#  'product': 94,
#  'which': 95,
#  'me': 96,
#  '3': 97,
#  'christmas': 98,
#  "don't": 99,
#  'easy': 100,
#  'by': 101,
#  '34': 102,
#  'put': 103,
#  'price': 104,
#  'off': 105,
#  'him': 106,
#  'still': 107,
#  'who': 108,
#  'now': 109,
#  'quality': 110,
#  'first': 111,
#  'gift': 112,
#  'make': 113,
#  'buy': 114,
#  'two': 115,
#  'recommend': 116,
#  'over': 117,
#  'after': 118,
#  'loved': 119,
#  'how': 120,
#  'nice': 121,
#  'any': 122,
#  'together': 123,
#  'playing': 124,
#  'their': 125,
#  'pieces': 126,
#  '5': 127,
#  'been': 128,
#  'its': 129,
#  '4': 130,
#  'could': 131,
#  'then': 132,
#  'back': 133,
#  'small': 134,
#  'think': 135,
#  'cute': 136,
#  'perfect': 137,
#  'box': 138,
#  'around': 139,
#  'into': 140,
#  'am': 141,
#  'go': 142,
#  'did': 143,
#  'lot': 144,
#  'way': 145,
#  "i'm": 146,
#  'does': 147,
#  'toys': 148,
#  'doll': 149,
#  'work': 150,
#  '1': 151,
#  'thing': 152,
#  'new': 153,
#  'cards': 154,
#  'better': 155,
#  'purchased': 156,
#  'big': 157,
#  'many': 158,
#  'pretty': 159,
#  'few': 160,
#  'enough': 161,
#  'see': 162,
#  'birthday': 163,
#  'figure': 164,
#  'used': 165,
#  'right': 166,
#  'size': 167,
#  'while': 168,
#  'since': 169,
#  'find': 170,
#  'child': 171,
#  'plastic': 172,
#  'different': 173,
#  'looks': 174,
#  "doesn't": 175,
#  'look': 176,
#  'down': 177,
#  'came': 178,
#  'take': 179,
#  'happy': 180,
#  "didn't": 181,
#  'bit': 182,
#  'though': 183,
#  'know': 184,
#  'again': 185,
#  'long': 186,
#  'most': 187,
#  'each': 188,
#  'hard': 189,
#  'want': 190,
#  'item': 191,
#  'games': 192,
#  'years': 193,
#  'best': 194,
#  'played': 195,
#  'day': 196,
#  'worth': 197,
#  'looking': 198,
#  'grandson': 199,
#  'thought': 200,
#  'sure': 201,
#  'another': 202,
#  'come': 203,
#  'every': 204,
#  'keep': 205,
#  'makes': 206,
#  'same': 207,
#  'durable': 208,
#  'before': 209,
#  'say': 210,
#  "can't": 211,
#  'money': 212,
#  'children': 213,
#  'something': 214,
#  'comes': 215,
#  '6': 216,
#  'both': 217,
#  'things': 218,
#  'need': 219,
#  'wanted': 220,
#  'however': 221,
#  'going': 222,
#  'amazon': 223,
#  'purchase': 224,
#  'own': 225,
#  'easily': 226,
#  'car': 227,
#  'should': 228,
#  'received': 229,
#  'puzzle': 230,
#  'last': 231,
#  'fit': 232,
#  'able': 233,
#  'being': 234,
#  'hours': 235,
#  'people': 236,
#  'actually': 237,
#  'family': 238,
#  'house': 239,
#  'never': 240,
#  'found': 241,
#  'definitely': 242,
#  'colors': 243,
#  'give': 244,
#  'once': 245,
#  'without': 246,
#  '10': 247,
#  'card': 248,
#  'ordered': 249,
#  'getting': 250,
#  'works': 251,
#  'where': 252,
#  'quite': 253,
#  'overall': 254,
#  "i've": 255,
#  'piece': 256,
#  'far': 257,
#  'always': 258,
#  'months': 259,
#  'highly': 260,
#  'cool': 261,
#  'real': 262,
#  'seems': 263,
#  'three': 264,
#  'sturdy': 265,
#  'through': 266,
#  'friends': 267,
#  'enjoy': 268,
#  'board': 269,
#  'took': 270,
#  'baby': 271,
#  'parts': 272,
#  'us': 273,
#  'party': 274,
#  'favorite': 275,
#  'having': 276,
#  'color': 277,
#  'batteries': 278,
#  'using': 279,
#  'part': 280,
#  'problem': 281,
#  'times': 282,
#  'ones': 283,
#  'granddaughter': 284,
#  'high': 285,
#  '8': 286,
#  'almost': 287,
#  'those': 288,
#  'hold': 289,
#  'plays': 290,
#  'arrived': 291,
#  'awesome': 292,
#  'month': 293,
#  'away': 294,
#  'likes': 295,
#  'soft': 296,
#  'figures': 297,
#  'yet': 298,
#  'light': 299,
#  'said': 300,
#  'wish': 301,
#  'top': 302,
#  'fan': 303,
#  'fast': 304,
#  'several': 305,
#  'hit': 306,
#  '7': 307,
#  'everything': 308,
#  'collection': 309,
#  'picture': 310,
#  'dolls': 311,
#  'ever': 312,
#  'may': 313,
#  'kid': 314,
#  'water': 315,
#  'super': 316,
#  'help': 317,
#  'expected': 318,
#  'side': 319,
#  'store': 320,
#  'disappointed': 321,
#  'minutes': 322,
#  'gave': 323,
#  'quickly': 324,
#  'order': 325,
#  'room': 326,
#  'fine': 327,
#  'here': 328,
#  'such': 329,
#  'days': 330,
#  'absolutely': 331,
#  'age': 332,
#  'lots': 333,
#  'gets': 334,
#  'place': 335,
#  'sets': 336,
#  'try': 337,
#  'must': 338,
#  'kit': 339,
#  'already': 340,
#  'cars': 341,
#  'lego': 342,
#  'battery': 343,
#  'buying': 344,
#  'anyone': 345,
#  'probably': 346,
#  'version': 347,
#  'bad': 348,
#  'cheap': 349,
#  "that's": 350,
#  'reviews': 351,
#  'model': 352,
#  'read': 353,
#  'hand': 354,
#  'large': 355,
#  'hands': 356,
#  'learning': 357,
#  'anything': 358,
#  'older': 359,
#  'turn': 360,
#  'head': 361,
#  'open': 362,
#  'excellent': 363,
#  'especially': 364,
#  'girl': 365,
#  'making': 366,
#  'paint': 367,
#  'might': 368,
#  'next': 369,
#  'less': 370,
#  "isn't": 371,
#  'feel': 372,
#  'inside': 373,
#  'exactly': 374,
#  'build': 375,
#  "he's": 376,
#  'young': 377,
#  'simple': 378,
#  'enjoyed': 379,
#  'learn': 380,
#  'case': 381,
#  'couple': 382,
#  'stars': 383,
#  'everyone': 384,
#  'smaller': 385,
#  'end': 386,
#  'add': 387,
#  'worked': 388,
#  'yr': 389,
#  'track': 390,
#  'excited': 391,
#  'ball': 392,
#  'went': 393,
#  'extra': 394,
#  'along': 395,
#  'difficult': 396,
#  'four': 397,
#  'star': 398,
#  'saw': 399,
#  'takes': 400,
#  'shipping': 401,
#  'boys': 402,
#  'apart': 403,
#  'table': 404,
#  "you're": 405,
#  'seem': 406,
#  'instead': 407,
#  'others': 408,
#  'sound': 409,
#  'why': 410,
#  'instructions': 411,
#  'move': 412,
#  'etc': 413,
#  'whole': 414,
#  'girls': 415,
#  'although': 416,
#  'original': 417,
#  'until': 418,
#  'needed': 419,
#  'beautiful': 420,
#  'addition': 421,
#  'value': 422,
#  'train': 423,
#  'fly': 424,
#  'nothing': 425,
#  'trying': 426,
#  'line': 427,
#  'second': 428,
#  'fact': 429,
#  'book': 430,
#  'huge': 431,
#  'done': 432,
#  'night': 433,
#  "won't": 434,
#  'stand': 435,
#  'liked': 436,
#  'putting': 437,
#  'let': 438,
#  'review': 439,
#  'looked': 440,
#  'present': 441,
#  'under': 442,
#  'ages': 443,
#  'husband': 444,
#  '9': 445,
#  'started': 446,
#  'seen': 447,
#  'maybe': 448,
#  'home': 449,
#  'sounds': 450,
#  'opened': 451,
#  'players': 452,
#  'goes': 453,
#  'bag': 454,
#  'amazing': 455,
#  'tried': 456,
#  'kind': 457,
#  'pleased': 458,
#  'educational': 459,
#  'least': 460,
#  "wasn't": 461,
#  'detail': 462,
#  'nephew': 463,
#  'hair': 464,
#  'face': 465,
#  'included': 466,
#  'design': 467,
#  'show': 468,
#  'start': 469,
#  '20': 470,
#  'boy': 471,
#  'items': 472,
#  'wonderful': 473,
#  'puzzles': 474,
#  'idea': 475,
#  "couldn't": 476,
#  'break': 477,
#  'music': 478,
#  'package': 479,
#  'bigger': 480,
#  'either': 481,
#  'stay': 482,
#  'deal': 483,
#  'adorable': 484,
#  'friend': 485,
#  'working': 486,
#  "i'd": 487,
#  'control': 488,
#  'action': 489,
#  'broke': 490,
#  "wouldn't": 491,
#  'itself': 492,
#  'red': 493,
#  'says': 494,
#  'plus': 495,
#  'wait': 496,
#  'expensive': 497,
#  'adults': 498,
#  'pictures': 499,
#  'half': 500,
#  'building': 501,
#  'player': 502,
#  "they're": 503,
#  'niece': 504,
#  'black': 505,
#  'blue': 506,
#  'else': 507,
#  'pack': 508,
#  'thank': 509,
#  'ago': 510,
#  'glad': 511,
#  'full': 512,
#  '12': 513,
#  'condition': 514,
#  'animals': 515,
#  'left': 516,
#  'enjoys': 517,
#  'wheels': 518,
#  'deck': 519,
#  'truck': 520,
#  'someone': 521,
#  'stuff': 522,
#  'life': 523,
#  'broken': 524,
#  'thanks': 525,
#  'bottom': 526,
#  'front': 527,
#  'white': 528,
#  'rather': 529,
#  'balls': 530,
#  'five': 531,
#  'perfectly': 532,
#  'characters': 533,
#  'point': 534,
#  'younger': 535,
#  'paper': 536,
#  'company': 537,
#  'longer': 538,
#  'wrong': 539,
#  'school': 540,
#  'problems': 541,
#  'keeps': 542,
#  'larger': 543,
#  'blocks': 544,
#  'built': 545,
#  'fall': 546,
#  'tell': 547,
#  'products': 548,
#  "she's": 549,
#  'run': 550,
#  'soon': 551,
#  'course': 552,
#  'guess': 553,
#  'series': 554,
#  'week': 555,
#  'myself': 556,
#  'lost': 557,
#  'needs': 558,
#  'sometimes': 559,
#  'movie': 560,
#  'mine': 561,
#  "haven't": 562,
#  'expect': 563,
#  'tiny': 564,
#  'lights': 565,
#  'adult': 566,
#  '15': 567,
#  'later': 568,
#  'doing': 569,
#  'change': 570,
#  'power': 571,
#  'helicopter': 572,
#  'quick': 573,
#  'close': 574,
#  'short': 575,
#  'given': 576,
#  'person': 577,
#  'number': 578,
#  'extremely': 579,
#  'cost': 580,
#  'packaging': 581,
#  'recommended': 582,
#  'ok': 583,
#  'dice': 584,
#  'fits': 585,
#  'decided': 586,
#  'barbie': 587,
#  '30': 588,
#  'button': 589,
#  'air': 590,
#  'push': 591,
#  'watch': 592,
#  'wood': 593,
#  'pull': 594,
#  "there's": 595,
#  'reason': 596,
#  'during': 597,
#  'bright': 598,
#  'finally': 599,
#  'space': 600,
#  'heavy': 601,
#  'plush': 602,
#  'easier': 603,
#  'floor': 604,
#  'weeks': 605,
#  'within': 606,
#  'stuffed': 607,
#  'seller': 608,
#  'eyes': 609,
#  'outside': 610,
#  'legs': 611,
#  'handle': 612,
#  'turned': 613,
#  'between': 614,
#  'feet': 615,
#  'parents': 616,
#  'pay': 617,
#  'job': 618,
#  'type': 619,
#  'grand': 620,
#  'toddler': 621,
#  'gun': 622,
#  "we've": 623,
#  'clear': 624,
#  'green': 625,
#  'sit': 626,
#  'pool': 627,
#  'mind': 628,
#  'complete': 629,
#  'return': 630,
#  'flying': 631,
#  'shape': 632,
#  'paid': 633,
#  'kept': 634,
#  "son's": 635,
#  'wants': 636,
#  'body': 637,
#  'often': 638,
#  'hope': 639,
#  'nicely': 640,
#  'rules': 641,
#  'held': 642,
#  'detailed': 643,
#  'taking': 644,
#  'dog': 645,
#  'believe': 646,
#  'free': 647,
#  'display': 648,
#  'yes': 649,
#  'care': 650,
#  'kitchen': 651,
#  'stickers': 652,
#  'forward': 653,
#  'assemble': 654,
#  'pick': 655,
#  'sister': 656,
#  'stick': 657,
#  'online': 658,
#  'issue': 659,
#  'reading': 660,
#  'brand': 661,
#  'animal': 662,
#  'brother': 663,
#  'base': 664,
#  'uses': 665,
#  'completely': 666,
#  'character': 667,
#  'level': 668,
#  'cannot': 669,
#  'hour': 670,
#  'experience': 671,
#  'accessories': 672,
#  'spent': 673,
#  'surprised': 674,
#  'attention': 675,
#  'similar': 676,
#  'story': 677,
#  'amount': 678,
#  'words': 679,
#  "aren't": 680,
#  'guy': 681,
#  'solid': 682,
#  'available': 683,
#  'motor': 684,
#  "you'll": 685,
#  'fairly': 686,
#  'thinking': 687,
#  'strong': 688,
#  'cut': 689,
#  'wooden': 690,
#  'slide': 691,
#  'stores': 692,
#  'understand': 693,
#  'sent': 694,
#  'regular': 695,
#  'immediately': 696,
#  'pink': 697,
#  'seat': 698,
#  'due': 699,
#  'material': 700,
#  'stop': 701,
#  'mom': 702,
#  'low': 703,
#  '18': 704,
#  'complaint': 705,
#  'system': 706,
#  'waste': 707,
#  'metal': 708,
#  'clean': 709,
#  'otherwise': 710,
#  'bed': 711,
#  'spend': 712,
#  'missing': 713,
#  'charge': 714,
#  'replacement': 715,
#  'daughters': 716,
#  'interesting': 717,
#  'books': 718,
#  'special': 719,
#  'turns': 720,
#  'name': 721,
#  'added': 722,
#  'weight': 723,
#  'glue': 724,
#  "i'll": 725,
#  'service': 726,
#  'gifts': 727,
#  'world': 728,
#  'totally': 729,
#  'description': 730,
#  "daughter's": 731,
#  'simply': 732,
#  'fantastic': 733,
#  '11': 734,
#  'anyway': 735,
#  'directions': 736,
#  'blast': 737,
#  'video': 738,
#  'details': 739,
#  'everywhere': 740,
#  'rest': 741,
#  'six': 742,
#  'seemed': 743,
#  'legos': 744,
#  'dark': 745,
#  'thrilled': 746,
#  'skills': 747,
#  'usually': 748,
#  'shipped': 749,
#  'helps': 750,
#  'unless': 751,
#  'group': 752,
#  'arms': 753,
#  'fans': 754,
#  'letters': 755,
#  'challenging': 756,
#  'knew': 757,
#  'asked': 758,
#  'impressed': 759,
#  'remote': 760,
#  'loud': 761,
#  'mode': 762,
#  'wall': 763,
#  'holds': 764,
#  'cheaper': 765,
#  'touch': 766,
#  'interest': 767,
#  'hot': 768,
#  'bear': 769,
#  'carry': 770,
#  'designed': 771,
#  'realistic': 772,
#  'flimsy': 773,
#  'giving': 774,
#  'holding': 775,
#  'colorful': 776,
#  'remember': 777,
#  'camera': 778,
#  'thomas': 779,
#  'storage': 780,
#  '100': 781,
#  'slightly': 782,
#  'actual': 783,
#  'features': 784,
#  'shapes': 785,
#  'described': 786,
#  'door': 787,
#  'pop': 788,
#  's': 789,
#  'plan': 790,
#  'watching': 791,
#  'coming': 792,
#  'ready': 793,
#  'issues': 794,
#  'entire': 795,
#  'wear': 796,
#  'supposed': 797,
#  'wars': 798,
#  'ended': 799,
#  'assembly': 800,
#  'roll': 801,
#  'safe': 802,
#  'points': 803,
#  'note': 804,
#  'interested': 805,
#  'unfortunately': 806,
#  'plane': 807,
#  'range': 808,
#  'variety': 809,
#  'construction': 810,
#  'fell': 811,
#  'expansion': 812,
#  'ride': 813,
#  'clothes': 814,
#  'based': 815,
#  'rubber': 816,
#  'past': 817,
#  'rc': 818,
#  'poor': 819,
#  'tool': 820,
#  'food': 821,
#  'except': 822,
#  'cover': 823,
#  'true': 824,
#  'told': 825,
#  'imagination': 826,
#  'careful': 827,
#  'gotten': 828,
#  'numbers': 829,
#  'tv': 830,
#  'gives': 831,
#  'feature': 832,
#  'scale': 833,
#  'today': 834,
#  'ship': 835,
#  'decent': 836,
#  'dress': 837,
#  'monster': 838,
#  'plenty': 839,
#  'become': 840,
#  'area': 841,
#  'challenge': 842,
#  'noise': 843,
#  'tail': 844,
#  'purchasing': 845,
#  'man': 846,
#  'morning': 847,
#  'moving': 848,
#  'screen': 849,
#  'future': 850,
#  'stuck': 851,
#  'art': 852,
#  'main': 853,
#  '50': 854,
#  'collector': 855,
#  'basic': 856,
#  'eye': 857,
#  'wife': 858,
#  'brought': 859,
#  'local': 860,
#  'against': 861,
#  'single': 862,
#  'strategy': 863,
#  'mini': 864,
#  'learned': 865,
#  'mouth': 866,
#  'straight': 867,
#  'annoying': 868,
#  'durability': 869,
#  'cake': 870,
#  'models': 871,
#  'attached': 872,
#  'funny': 873,
#  'd': 874,
#  'oh': 875,
#  'matter': 876,
#  'match': 877,
#  'trouble': 878,
#  'rough': 879,
#  'inches': 880,
#  'questions': 881,
#  'cat': 882,
#  'cardboard': 883,
#  'buttons': 884,
#  'non': 885,
#  'classic': 886,
#  'dont': 887,
#  'replace': 888,
#  'creative': 889,
#  'trains': 890,
#  'himself': 891,
#  'felt': 892,
#  'holes': 893,
#  'onto': 894,
#  'wheel': 895,
#  'crazy': 896,
#  'teach': 897,
#  'olds': 898,
#  'tracks': 899,
#  'style': 900,
#  'dad': 901,
#  'lol': 902,
#  'grandchildren': 903,
#  'loose': 904,
#  'feels': 905,
#  'bring': 906,
#  'choice': 907,
#  'thin': 908,
#  'taken': 909,
#  'unique': 910,
#  'create': 911,
#  'figured': 912,
#  'unit': 913,
#  'leave': 914,
#  'save': 915,
#  'speed': 916,
#  'melissa': 917,
#  'doug': 918,
#  'expecting': 919,
#  'delivery': 920,
#  'sitting': 921,
#  'themselves': 922,
#  'chance': 923,
#  'sons': 924,
#  'called': 925,
#  'including': 926,
#  'flight': 927,
#  'songs': 928,
#  'standard': 929,
#  'tiles': 930,
#  "hasn't": 931,
#  'tall': 932,
#  'opening': 933,
#  'recently': 934,
#  'alot': 935,
#  'hear': 936,
#  'compared': 937,
#  'neat': 938,
#  'computer': 939,
#  'santa': 940,
#  'disney': 941,
#  'shows': 942,
#  'theme': 943,
#  'switch': 944,
#  'means': 945,
#  'win': 946,
#  'customer': 947,
#  'lose': 948,
#  'word': 949,
#  'cube': 950,
#  'constantly': 951,
#  'x': 952,
#  'follow': 953,
#  'painted': 954,
#  'hang': 955,
#  'r': 956,
#  'seeing': 957,
#  'flat': 958,
#  'please': 959,
#  'project': 960,
#  'send': 961,
#  'across': 962,
#  'sort': 963,
#  '99': 964,
#  'yellow': 965,
#  'shelf': 966,
#  'machine': 967,
#  'sold': 968,
#  'sized': 969,
#  'okay': 970,
#  'sand': 971,
#  'busy': 972,
#  'castle': 973,
#  'moves': 974,
#  'fix': 975,
#  'snap': 976,
#  'phone': 977,
#  'fire': 978,
#  'horse': 979,
#  'allows': 980,
#  'colored': 981,
#  'ways': 982,
#  'suggest': 983,
#  'check': 984,
#  'damage': 985,
#  'multiple': 986,
#  'running': 987,
#  'packs': 988,
#  'practice': 989,
#  'properly': 990,
#  'additional': 991,
#  'satisfied': 992,
#  'o': 993,
#  'pet': 994,
#  'advertised': 995,
#  'early': 996,
#  'round': 997,
#  'hoping': 998,
#  'receive': 999,
#  'picked': 1000,
#  ...}

# %%
sequences =tokenizer.texts_to_sequences(train_sent)
padded = pad_sequences(sequences,maxlen=max_length,truncating=trunc_type)
testing_sequences=tokenizer.texts_to_sequences(test_sent)
testing_padded = pad_sequences(testing_sequences,maxlen=max_length)

# %%
padded
# Out:
# array([[   0,    0,    0, ..., 1110,  104,  548],
#        [   0,    0,    0, ...,   61,  125,  148],
#        [   4,  397,   52, ...,  562,  195,   12],
#        ...,
#        [   0,    0,    0, ..., 1103,   23,   79],
#        [   0,    0,    0, ...,    3,  397,  383],
#        [   0,    0,    0, ...,    4,  304,  275]])

# %%
import tensorflow as tf

# %%
model=tf.keras.Sequential()
model.add(tf.keras.layers.Embedding(vocab_size,embedding_dim,input_length=max_length))
model.add(tf.keras.layers.SimpleRNN(32))
model.add(tf.keras.layers.Dense(10,activation='relu'))
model.add(tf.keras.layers.Dense(1,activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From c:\Users\Prathamesh\anaconda3\envs\Deep_Learning\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
history = model.fit(padded,train_labels,epochs=5,validation_data=(testing_padded,test_labels))
# Out:
# Epoch 1/5
# WARNING:tensorflow:From c:\Users\Prathamesh\anaconda3\envs\Deep_Learning\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Prathamesh\anaconda3\envs\Deep_Learning\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 43688/43688 [==============================] - 725s 16ms/step - loss: 0.2812 - accuracy: 0.8850 - val_loss: 0.2862 - val_accuracy: 0.8821
# Epoch 2/5
# 43688/43688 [==============================] - 804s 18ms/step - loss: 0.2888 - accuracy: 0.8827 - val_loss: 0.2928 - val_accuracy: 0.8786
# Epoch 3/5
# 43688/43688 [==============================] - 703s 16ms/step - loss: 0.3201 - accuracy: 0.8684 - val_loss: 0.3021 - val_accuracy: 0.8753
# Epoch 4/5
#  1216/43688 [..............................] - ETA: 10:04 - loss: 0.3052 - accuracy: 0.8768
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 history = model.fit(padded,train_labels,epochs=5,validation_data=(testing_padded,test_labels))
#
# File c:\Users\Prathamesh\anaconda3\envs\Deep_Learning\Lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Prathamesh\anaconda3\envs\Deep_Learning\Lib\site-packages\keras\src\engine\training.py:1807, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1799 with tf.profiler.experimental.Trace(
#    1800     "train",
#    1801     epoch_num=epoch,
#    (...)
#    1804     _r=1,
#    1805 ):
#    1806     callbacks.on_train_batch_begin(step)
# -> 1807     tmp_logs = self.train_function(iterator)
#    1808     if data_handler.should_sync:
#    1809         context.async_wait()
#
# File c:\Users\Prathamesh\anaconda3\envs\Deep_Learning\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Prathamesh\anaconda3\envs\Deep_Learning\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\Prathamesh\anaconda3\envs\Deep_Learning\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:868, in Function._call(self, *args, **kwds)
#     865   self._lock.release()
#     866   # In this case we have created variables on the first call, so we run the
#     867   # defunned version which is guaranteed to never create variables.
# --> 868   return tracing_compilation.call_function(
#     869       args, kwds, self._no_variable_creation_config
#     870   )
#     871 elif self._variable_creation_config is not None:
#     872   # Release the lock early so that multiple threads can perform the call
#     873   # in parallel.
#     874   self._lock.release()
#
# File c:\Users\Prathamesh\anaconda3\envs\Deep_Learning\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\Prathamesh\anaconda3\envs\Deep_Learning\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\Prathamesh\anaconda3\envs\Deep_Learning\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\Prathamesh\anaconda3\envs\Deep_Learning\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\Prathamesh\anaconda3\envs\Deep_Learning\Lib\site-packages\tensorflow\python\eager\context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)
#    1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File c:\Users\Prathamesh\anaconda3\envs\Deep_Learning\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
